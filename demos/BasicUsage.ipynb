# %% [markdown]
# # Demo: Basic Usage
#
# This notebook contains a demonstration of a common usage of CXAS. We display how to segment CXR anatomy in different data types, how to extract features, how to store the predictions, and how to visualize them.
#
# We use a basic frontal CXR as example.

# %% [markdown]
# ## Installation of CXAS

# %%
! pip install cxas
# Out:
# Requirement already satisfied: cxas in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (0.0.17)
# Requirement already satisfied: cython in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (3.0.11)
# Requirement already satisfied: torch in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (2.6.0)
# Requirement already satisfied: gdown in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (5.2.0)
# Requirement already satisfied: torchvision in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (0.21.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (1.26.4)
# Requirement already satisfied: SimpleITK in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (2.4.1)
# Requirement already satisfied: pydicom==2.0.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (2.0.0)
# Requirement already satisfied: pydicom-seg==0.4.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (0.4.1)
# Requirement already satisfied: scikit-image in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (0.25.1)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (1.5.2)
# Requirement already satisfied: opencv-python in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (4.11.0.86)
# Requirement already satisfied: colorcet in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (3.1.0)
# Requirement already satisfied: pycocotools in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (2.0.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (2.2.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from cxas) (4.67.0)
# Requirement already satisfied: jsonschema<4.0.0,>=3.2.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from pydicom-seg==0.4.1->cxas) (3.2.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from gdown->cxas) (4.12.3)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from gdown->cxas) (3.16.1)
# Requirement already satisfied: requests[socks] in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from gdown->cxas) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from pandas->cxas) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from pandas->cxas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from pandas->cxas) (2025.1)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from pycocotools->cxas) (3.10.0)
# Requirement already satisfied: scipy>=1.11.2 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (2025.1.10)
# Requirement already satisfied: packaging>=21 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-image->cxas) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-learn->cxas) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from scikit-learn->cxas) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from torch->cxas) (4.12.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from torch->cxas) (3.1.5)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from torch->cxas) (2025.2.0)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from torch->cxas) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from torch->cxas) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from sympy==1.13.1->torch->cxas) (1.3.0)
# Requirement already satisfied: attrs>=17.4.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg==0.4.1->cxas) (25.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg==0.4.1->cxas) (0.20.0)
# Requirement already satisfied: six>=1.11.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from jsonschema<4.0.0,>=3.2.0->pydicom-seg==0.4.1->cxas) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from matplotlib>=2.1.0->pycocotools->cxas) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from matplotlib>=2.1.0->pycocotools->cxas) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from matplotlib>=2.1.0->pycocotools->cxas) (4.55.8)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from matplotlib>=2.1.0->pycocotools->cxas) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from matplotlib>=2.1.0->pycocotools->cxas) (3.2.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from beautifulsoup4->gdown->cxas) (2.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from jinja2->torch->cxas) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from requests[socks]->gdown->cxas) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from requests[socks]->gdown->cxas) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from requests[socks]->gdown->cxas) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from requests[socks]->gdown->cxas) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/anaconda3/envs/cxas/lib/python3.13/site-packages (from requests[socks]->gdown->cxas) (1.7.1)

# %% [markdown]
# ## Import necessary packages

# %%
import torch
import numpy as np
from PIL import Image
import shutil
import os
os.chdir('..')
from cxas import CXAS

# %% [markdown]
# ## Process images

# %%
model = CXAS(
    model_name = 'UNet_ResNet50_default',
    gpus       = 'cpu'
)

# %% [markdown]
# # Process tensors

# %%
sample_tensor = torch.randn(1,3,512,512).to('cpu')

_ = model(sample_tensor)

sample_output = model({'data': sample_tensor})

for k in sample_output.keys():
    if type(sample_output[k]) in [np.ndarray, torch.Tensor]:
        print('{}: \n\t shape - {} \n\t dtype - {} \n'.format(k, sample_output[k].shape, sample_output[k].dtype))
    else:
        print('{}: \n\t example - {}\n\t dtype - {} \n'.format(k, sample_output[k], type(sample_output[k])))
# Out:
# feats:
# 	 shape - torch.Size([1, 128, 128, 128])
# 	 dtype - torch.float32
#
# logits:
# 	 shape - torch.Size([1, 159, 512, 512])
# 	 dtype - torch.float32
#
# data:
# 	 shape - torch.Size([1, 3, 512, 512])
# 	 dtype - torch.float32
#
# segmentation_preds:
# 	 shape - torch.Size([1, 159, 512, 512])
# 	 dtype - torch.bool

# %% [markdown]
# # Process Image files

# %%
# Dicom images
path = 'images/126_IM-0176-2002.dcm'

sample_output = model.process_file(
        filename = path
        )

#  ---------------------------------------------------------------------

# png  files
path = 'images/00003440_000.png'

sample_output = model.process_file(
        filename = path
        )

#  ---------------------------------------------------------------------

# jpg files
path = 'images/00003440_000.jpg'

sample_output = model.process_file(
        filename = path
        )

#  ---------------------------------------------------------------------


for k in sample_output.keys():
    if type(sample_output[k]) in [np.ndarray, torch.Tensor]:
        print('{}: \n\t shape - {} \n\t dtype - {} \n'.format(k, sample_output[k].shape, sample_output[k].dtype))
    else:
        print('{}: \n\t example - {}\n\t dtype - {} \n'.format(k, sample_output[k], type(sample_output[k])))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 4
#       1 # Dicom images
#       2 path = 'images/126_IM-0176-2002.dcm'
# ----> 4 sample_output = model.process_file(
#       5         filename = path
#       6         )
#       8 #  ---------------------------------------------------------------------
#       9
#      10 # png  files
#      11 path = 'images/00003440_000.png'
#
# File ~/workspace/research/ChestXRayAnatomySegmentation/cxas/segmentor.py:58, in CXAS.process_file(self, filename, do_store, output_directory, create, storage_type)
#      36 def process_file(
#      37     self,
#      38     filename: str,
#    (...)
#      42     storage_type: str = "npy",
#      43 ) -> np.array:
#      44     """
#      45     Create segmentation of image file, can store predictions in desired directory in desired format
#      46
#    (...)
#      56         prediction: model output dictionary containing [feats: network features , logits: unnormalized network logit scores, data: input data, segmentation_preds: thresholded multi-label segmentations]
#      57     """
# ---> 58     assert os.path.isfile(filename)
#      60     if not create:
#      61         assert os.path.isdir(output_directory)
#
# AssertionError:

# %% [markdown]
# # Store Results

# %%
path = 'images/126_IM-0176-2002.dcm'
out_path = './out_segs'

print('Store each segmentation label as dicom-seg (.dcm) in folder \n \
        This is only possible for dicom files!')
print('Does the out_path exists:', os.path.isdir(out_path))

_ = model.process_file(
        filename = path,
        do_store = True, 
        output_directory = out_path,
        storage_type = 'dicom-seg',
        )

print('First five Files in directory:', [os.path.join(dp, f) 
                              for dp, dn, fn in os.walk(os.path.expanduser(out_path)) for f in fn][:5])
shutil.rmtree(out_path)

print('Store as .npy-file')
print('Does the out_path exists:', os.path.isdir(out_path))

_ = model.process_file(
        filename = path,
        do_store = True, 
        output_directory = out_path,
        storage_type = 'npy',
        )

print('Files in directory:', os.listdir(out_path))
shutil.rmtree(out_path)

print('Store as .npz-file')
print('Does the out_path exists:', os.path.isdir(out_path))

_ = model.process_file(
        filename = path,
        do_store = True, 
        output_directory = out_path,
        storage_type = 'npz',
        )

print('Files in directory:', os.listdir(out_path))
shutil.rmtree(out_path)

print('Store each segmentation label as jpg in folder')
print('Does the out_path exists:', os.path.isdir(out_path))

_ = model.process_file(
        filename = path,
        do_store = True, 
        output_directory = out_path,
        storage_type = 'jpg',
        )

print('First five Files in directory:', [os.path.join(dp, f) 
                              for dp, dn, fn in os.walk(os.path.expanduser(out_path)) for f in fn][:5])
shutil.rmtree(out_path)

print('Store segmentation as json in coco format')
print('Does the out_path exists:', os.path.isdir(out_path))
_ = model.process_file(
        filename = path,
        do_store = True, 
        output_directory = out_path,
        storage_type = 'json',
        )

print('Files in directory:', os.listdir(out_path))

shutil.rmtree(out_path)
# Out:
# Store each segmentation label as dicom-seg (.dcm) in folder
#          This is only possible for dicom files!
# Does the out_path exists: True
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bd50fbfa40): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bdcc4bb1f0): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
# First five Files in directory: ['./out_segs/126_IM-0176-2002/i_anterior 1st rib left.dcm', './out_segs/126_IM-0176-2002/i_anterior 1st rib right.dcm', './out_segs/126_IM-0176-2002/i_esophagus.dcm', './out_segs/126_IM-0176-2002/i_posterior 4th rib.dcm', './out_segs/126_IM-0176-2002/i_small bowel.dcm']
# Store as .npy-file
# Does the out_path exists: False
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bde8ed7f90): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
# Files in directory: ['126_IM-0176-2002.npy']
# Store as .npz-file
# Does the out_path exists: False
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bde8ed7f90): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
# Files in directory: ['126_IM-0176-2002.npz']
# Store each segmentation label as jpg in folder
# Does the out_path exists: False
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bde8efd590): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
# First five Files in directory: ['./out_segs/126_IM-0176-2002/126_IM-0176-2002_anterior 8th rib left.jpg', './out_segs/126_IM-0176-2002/126_IM-0176-2002_lung base.jpg', './out_segs/126_IM-0176-2002/126_IM-0176-2002_vertebrae T9.jpg', './out_segs/126_IM-0176-2002/126_IM-0176-2002_pulmonary artery.jpg', './out_segs/126_IM-0176-2002/126_IM-0176-2002_vertebrae C3.jpg']
# Store segmentation as json in coco format
# Does the out_path exists: False
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/GDCM/src/itkGDCMImageIO.cxx, line 359
# GDCMImageIO (0x55bdcd00d5d0): Converting from MONOCHROME1 to MONOCHROME2 may impact the meaning of DICOM attributes related to pixel values.
# Files in directory: ['126_IM-0176-2002.json']
